# %% [markdown]
# # 🧠 Sentiment and Topic Analysis of Global Reactions to Donald Trump's 2025 Statement on Nigeria
#
# ## 📘 Project Overview
# This project analyzes public reactions to Donald Trump’s 2025 statement about Nigeria using Natural Language Processing (NLP).
# We’ll collect and analyze tweets and news articles to understand:
# - The **overall sentiment** (positive, negative, neutral)
# - The **dominant topics and themes** being discussed
# - The **key entities** (people, countries, organizations) mentioned
# - How sentiment and discussion evolved **over time**
#
# Ultimately, this project demonstrates how Data Science and NLP can quantify social media reaction and provide meaningful insights into global political discourse.

# %% [markdown]
# ## 🎯 Research Questions
# 1. What is the general public sentiment toward Trump’s statement on Nigeria?
# 2. Which countries or regions reacted most strongly?
# 3. What dominant topics and narratives emerged?
# 4. Which entities (e.g., Trump, Nigeria, Christians) were most frequently associated with each sentiment type?
# 5. Did sentiment change over time following the post?

# %% [markdown]
# ## 🧾 Project Objectives
# - Collect real-world tweets and articles related to Trump’s statement.
# - Clean, preprocess, and analyze textual data.
# - Apply **Sentiment Analysis** (VADER + Transformer models).
# - Apply **Topic Modeling** (LDA / BERTopic) to uncover key discussion themes.
# - Perform **Named Entity Recognition (NER)** to identify main subjects.
# - Visualize findings and communicate insights effectively.

# %%
# !pip install nltk

# %%
### 🟩 **CODE CELL 2 — Verify Imports**

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# import snscrape.modules.twitter as sntwitter
import torch
import spacy

print("✅ All core packages imported successfully!")
# Out:
# ✅ All core packages imported successfully!
